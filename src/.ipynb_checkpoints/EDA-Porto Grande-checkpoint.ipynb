# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mtl
import scipy.stats as st
import statsmodels.api as sm
import missingno  as msno
import matplotlib.pyplot as plt

# %%
sns.set()
plt.style.use('ggplot')
from IPython.core.pylabtools import figsize
figsize(10, 8)

# %% [markdown]
# # Trabalhando com a base de Portogrande

# %% [markdown]
# - ### Vamos conhecer um pouco sobre a base de dados

# %%
portogrande = pd.read_csv('../data/oiapoque.txt')

# %%
# dimensão do dataframe
portogrande.shape
# Out:
# (3144, 20)

# %%
# features
portogrande.columns
# Out:
# Index(['codigo_estacao', 'data', 'hora', 'temp_inst', 'temp_max', 'temp_min',
#        'umid_inst', 'umid_max', 'umid_min', 'pto_orvalho_inst',
#        'pto_orvalho_max', 'pto_orvalho_min', 'pressao', 'pressao_max',
#        'pressao_min', 'vento_vel', 'vento_direcao', 'vento_rajada', 'radiacao',
#        'precipitacao'],
#       dtype='object')

# %%
# algumas informações
portogrande.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3144 entries, 0 to 3143
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   codigo_estacao    3144 non-null   object
#  1   data              3144 non-null   object
#  2   hora              3144 non-null   int64
#  3   temp_inst         3144 non-null   float64
#  4   temp_max          3144 non-null   float64
#  5   temp_min          3144 non-null   float64
#  6   umid_inst         3144 non-null   int64
#  7   umid_max          3144 non-null   int64
#  8   umid_min          3144 non-null   int64
#  9   pto_orvalho_inst  3144 non-null   float64
#  10  pto_orvalho_max   3144 non-null   float64
#  11  pto_orvalho_min   3144 non-null   float64
#  12  pressao           3144 non-null   float64
#  13  pressao_max       3144 non-null   float64
#  14  pressao_min       3144 non-null   float64
#  15  vento_vel         3143 non-null   float64
#  16  vento_direcao     3142 non-null   float64
#  17  vento_rajada      3142 non-null   float64
#  18  radiacao          3144 non-null   float64
#  19  precipitacao      3144 non-null   float64
# dtypes: float64(14), int64(4), object(2)
# memory usage: 491.4+ KB

# %%
# tabela percentual de dados faltantes

features_numericas = ["hora","temp_inst", "temp_max", "temp_min", "umid_inst","umid_max","umid_min",
                      "pto_orvalho_inst", "pto_orvalho_max", "pto_orvalho_min","pressao", "vento_vel", 
                      "vento_direcao", "vento_rajada", "radiacao","precipitacao"]

df = portogrande[features_numericas]


total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)


missing_data = pd.concat([total, percent], axis=1,join='outer', keys=['Dados Ausentes', '% Percentual'])
missing_data.index.name =' Variaveis numericas'
missing_data.head(20)
# Out:
#                       Dados Ausentes  % Percentual
#  Variaveis numericas
# vento_rajada                       2      0.000636
# vento_direcao                      2      0.000636
# vento_vel                          1      0.000318
# precipitacao                       0      0.000000
# radiacao                           0      0.000000
# pressao                            0      0.000000
# pto_orvalho_min                    0      0.000000
# pto_orvalho_max                    0      0.000000
# pto_orvalho_inst                   0      0.000000
# umid_min                           0      0.000000
# umid_max                           0      0.000000
# umid_inst                          0      0.000000
# temp_min                           0      0.000000
# temp_max                           0      0.000000
# temp_inst                          0      0.000000
# hora                               0      0.000000

# %%
# 0s 10 valore que mais se repetem na coluna precipitação
portogrande.precipitacao.value_counts().head(10)
# Out:
# 0.0    2527
# 0.2     182
# 0.4      72
# 0.6      54
# 0.8      38
# 1.0      26
# 1.2      19
# 2.4      14
# 1.4      14
# 2.2      14
# Name: precipitacao, dtype: int64

# %%
# algumas caracteristicas estatisticas
portogrande.describe()
# Out:
#               hora    temp_inst     temp_max     temp_min    umid_inst  \
# count  3144.000000  3144.000000  3144.000000  3144.000000  3144.000000
# mean     11.500000    25.367430    25.821501    24.948823    91.631997
# std       6.923288     2.327578     2.578945     2.065242    11.071819
# min       0.000000    20.300000    20.400000    20.300000    55.000000
# 25%       5.750000    23.700000    23.900000    23.500000    86.000000
# 50%      11.500000    24.700000    25.000000    24.400000    97.000000
# 75%      17.250000    27.000000    27.800000    26.200000   100.000000
# max      23.000000    32.300000    32.700000    31.400000   100.000000
#
#           umid_max     umid_min  pto_orvalho_inst  pto_orvalho_max  \
# count  3144.000000  3144.000000       3144.000000      3144.000000
# mean     93.704517    89.415394         23.750350        24.175318
# std       9.091337    12.847666          1.011939         1.109483
# min      57.000000    48.000000         19.900000        20.400000
# 25%      91.000000    81.000000         23.100000        23.500000
# 50%      98.000000    96.000000         23.800000        24.200000
# 75%     100.000000   100.000000         24.500000        25.000000
# max     100.000000   100.000000         26.600000        27.400000
#
#        pto_orvalho_min      pressao  pressao_max  pressao_min    vento_vel  \
# count      3144.000000  3144.000000  3144.000000  3144.000000  3143.000000
# mean         23.376940  1011.113709  1011.388772  1010.837913     0.974356
# std           0.976497     1.535141     1.524238     1.519784     0.775646
# min          19.300000  1005.800000  1006.000000  1005.700000     0.100000
# 25%          22.800000  1010.000000  1010.300000  1009.700000     0.400000
# 50%          23.500000  1011.100000  1011.400000  1010.800000     0.700000
# 75%          24.100000  1012.200000  1012.500000  1011.900000     1.400000
# max          26.100000  1016.300000  1016.400000  1015.800000     3.900000
#
#        vento_direcao  vento_rajada     radiacao  precipitacao
# count    3142.000000   3142.000000  3144.000000   3144.000000
# mean      111.135901      3.075589   605.612084      0.415776
# std        80.274725      2.322550   849.589963      1.732541
# min         1.000000      0.500000    -3.540000      0.000000
# 25%        49.000000      1.100000    -2.300000      0.000000
# 50%        95.500000      2.100000    33.835000      0.000000
# 75%       144.000000      4.900000  1197.500000      0.000000
# max       360.000000     19.000000  3638.000000     25.800000

# %%
# Variaveis numéricas
varNum = portogrande.select_dtypes(include=[np.number])
varNum.columns
# Out:
# Index(['hora', 'temp_inst', 'temp_max', 'temp_min', 'umid_inst', 'umid_max',
#        'umid_min', 'pto_orvalho_inst', 'pto_orvalho_max', 'pto_orvalho_min',
#        'pressao', 'pressao_max', 'pressao_min', 'vento_vel', 'vento_direcao',
#        'vento_rajada', 'radiacao', 'precipitacao'],
#       dtype='object')

# %%
# variaveis categoricas
varCat = portogrande.select_dtypes(include=[np.object])
varCat.columns
# Out:
# Index(['codigo_estacao', 'data'], dtype='object')

# %%
# resumindo
print(f'Total de Variaveis Numericas: {varNum.columns.value_counts().sum()}')
print(f'Total de Variaveis Categoricas: {varCat.columns.value_counts().sum()}')
# Out:
# Total de Variaveis Numericas: 18
# Total de Variaveis Categoricas: 2

# %% [markdown]
# # Visualizando Valores Ausentes

# %% [markdown]
# - ### Matriz de Nulidade

# %%
msno.matrix(portogrande)

# %% [markdown]
# - ## HeatMap de Nulidade
#
# Mede a correlação de nulidade: Quão fortemente a presença ou ausência de uma variável afeta a presença de outra:
#
# ### Legenda:
#
# - A correlação de nulidade varia de -1 a 0
# - correlação de nulidade varia de -1 (se uma variável parece a outra definitivamente não aparece)
# - Se for 0 (variáveis que aparecem ou não aparecem não têm efeito uma sobre a outra)
# - Se for 1 (se uma variável aparece, a outra definitivamente também tem influencia sobre a outra)
# - As entradas marcadas <1ou > -1 estão com uma correlação próxima de ser exatamente negativa ou
#   positiva.

# %%
msno.heatmap(portogrande)

# %% [markdown]
# - ## Grafíco de Barras de Nulidade

# %%
msno.bar(portogrande.sample(1000))

# %% [markdown]
# # Estimando os valores de Skewness e Kurtose

# %%
# Estimando Skewness 
portogrande.skew()
# Out:
# hora                0.000000
# temp_inst           0.664240
# temp_max            0.596310
# temp_min            0.694783
# umid_inst          -1.320267
# umid_max           -1.635387
# umid_min           -1.058011
# pto_orvalho_inst   -0.393982
# pto_orvalho_max    -0.157640
# pto_orvalho_min    -0.644434
# pressao             0.093542
# pressao_max         0.041343
# pressao_min         0.140911
# vento_vel           1.248220
# vento_direcao       1.191153
# vento_rajada        0.933058
# radiacao            1.219781
# precipitacao        7.445198
# dtype: float64

# %%
# grafico dos valores de Skewness do dataset
sns.distplot(portogrande.skew(),color='blue',axlabel ='Skewness')

# %%
# Estimando Kurtose
portogrande.kurt()
# Out:
# hora                -1.204180
# temp_inst           -0.372849
# temp_max            -0.672397
# temp_min            -0.060582
# umid_inst            0.637986
# umid_max             1.828974
# umid_min            -0.135785
# pto_orvalho_inst     0.062540
# pto_orvalho_max     -0.168900
# pto_orvalho_min      0.263765
# pressao             -0.196531
# pressao_max         -0.188916
# pressao_min         -0.159870
# vento_vel            0.724086
# vento_direcao        1.159220
# vento_rajada         0.272231
# radiacao             0.284509
# precipitacao        72.769119
# dtype: float64

# %%
# Comparando a distribuição e verificando sua Kurtose
plt.figure(figsize = (12,8))
sns.distplot(portogrande.kurt(),color='r',axlabel ='Kurtosis',norm_hist= False, kde = True,rug = False)
plt.show()

# %%
# precipitação
plt.hist(portogrande['precipitacao'],orientation = 'vertical',histtype = 'bar', color ='blue')
plt.show()

# %%
target = np.log(portogrande['umid_inst'])
target.skew()
plt.hist(target,color='blue')
# Out:
# (array([  14.,   39.,   67.,   89.,  159.,  125.,  187.,  216.,  366.,
#         1882.]),
#  array([4.00733319, 4.06711689, 4.12690059, 4.18668429, 4.24646799,
#         4.30625169, 4.36603539, 4.42581909, 4.48560279, 4.54538649,
#         4.60517019]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Correlação

# %% [markdown]
# - ## Dendrograma
#
# Permite correlacionar mais completamente a conclusão das variáveis, revelando tendências mais profundas do que as pares aos pares visíveis no mapa de calor da correlação:

# %%
msno.dendrogram(portogrande)

# %% [markdown]
# - ### Matrix de Correlação

# %%
corr = portogrande.corr(method = 'pearson')
corr
# Out:
#                       hora  temp_inst  temp_max  temp_min  umid_inst  \
# hora              1.000000   0.595583  0.644949  0.594250  -0.548396
# temp_inst         0.595583   1.000000  0.972567  0.965786  -0.911924
# temp_max          0.644949   0.972567  1.000000  0.965284  -0.897745
# temp_min          0.594250   0.965786  0.965284  1.000000  -0.883587
# umid_inst        -0.548396  -0.911924 -0.897745 -0.883587   1.000000
# umid_max         -0.540653  -0.849003 -0.863110 -0.880972   0.954240
# umid_min         -0.610376  -0.897198 -0.935234 -0.892807   0.963835
# pto_orvalho_inst  0.190745   0.282118  0.260516  0.260811   0.130883
# pto_orvalho_max   0.357933   0.537735  0.523716  0.499825  -0.180371
# pto_orvalho_min  -0.006803   0.039634  0.009978  0.059172   0.339957
# pressao          -0.314857  -0.136604 -0.179262 -0.234732   0.061125
# pressao_max      -0.294663  -0.047857 -0.097462 -0.150602  -0.026183
# pressao_min      -0.317889  -0.084691 -0.132406 -0.181456   0.002942
# vento_vel         0.507875   0.745177  0.753907  0.712378  -0.809376
# vento_direcao    -0.214756  -0.279347 -0.301592 -0.307094   0.337797
# vento_rajada      0.612274   0.753394  0.805101  0.740298  -0.767147
# radiacao          0.459093   0.864859  0.822624  0.761947  -0.852347
# precipitacao      0.087173  -0.043121  0.012613 -0.033898   0.107823
#
#                   umid_max  umid_min  pto_orvalho_inst  pto_orvalho_max  \
# hora             -0.540653 -0.610376          0.190745         0.357933
# temp_inst        -0.849003 -0.897198          0.282118         0.537735
# temp_max         -0.863110 -0.935234          0.260516         0.523716
# temp_min         -0.880972 -0.892807          0.260811         0.499825
# umid_inst         0.954240  0.963835          0.130883        -0.180371
# umid_max          1.000000  0.948132          0.187177        -0.065674
# umid_min          0.948132  1.000000          0.070139        -0.215599
# pto_orvalho_inst  0.187177  0.070139          1.000000         0.896903
# pto_orvalho_max  -0.065674 -0.215599          0.896903         1.000000
# pto_orvalho_min   0.393455  0.322218          0.896958         0.780659
# pressao           0.141879  0.113458         -0.171506        -0.168556
# pressao_max       0.063261  0.033288         -0.166886        -0.131097
# pressao_min       0.087968  0.061195         -0.184718        -0.159357
# vento_vel        -0.753988 -0.792214         -0.071580         0.217870
# vento_direcao     0.353003  0.346896          0.103949         0.001301
# vento_rajada     -0.737665 -0.817895          0.059650         0.313763
# radiacao         -0.726327 -0.809002          0.100398         0.395582
# precipitacao      0.101092  0.048973          0.142016         0.154190
#
#                   pto_orvalho_min   pressao  pressao_max  pressao_min  \
# hora                    -0.006803 -0.314857    -0.294663    -0.317889
# temp_inst                0.039634 -0.136604    -0.047857    -0.084691
# temp_max                 0.009978 -0.179262    -0.097462    -0.132406
# temp_min                 0.059172 -0.234732    -0.150602    -0.181456
# umid_inst                0.339957  0.061125    -0.026183     0.002942
# umid_max                 0.393455  0.141879     0.063261     0.087968
# umid_min                 0.322218  0.113458     0.033288     0.061195
# pto_orvalho_inst         0.896958 -0.171506    -0.166886    -0.184718
# pto_orvalho_max          0.780659 -0.168556    -0.131097    -0.159357
# pto_orvalho_min          1.000000 -0.172826    -0.189645    -0.193765
# pressao                 -0.172826  1.000000     0.974500     0.980527
# pressao_max             -0.189645  0.974500     1.000000     0.984553
# pressao_min             -0.193765  0.980527     0.984553     1.000000
# vento_vel               -0.236221 -0.035955     0.035348     0.011564
# vento_direcao            0.137937  0.106557     0.101206     0.105036
# vento_rajada            -0.160736 -0.130401    -0.063660    -0.089884
# radiacao                -0.148546  0.064973     0.176059     0.134455
# precipitacao             0.130741 -0.015621    -0.010277    -0.022630
#
#                   vento_vel  vento_direcao  vento_rajada  radiacao  \
# hora               0.507875      -0.214756      0.612274  0.459093
# temp_inst          0.745177      -0.279347      0.753394  0.864859
# temp_max           0.753907      -0.301592      0.805101  0.822624
# temp_min           0.712378      -0.307094      0.740298  0.761947
# umid_inst         -0.809376       0.337797     -0.767147 -0.852347
# umid_max          -0.753988       0.353003     -0.737665 -0.726327
# umid_min          -0.792214       0.346896     -0.817895 -0.809002
# pto_orvalho_inst  -0.071580       0.103949      0.059650  0.100398
# pto_orvalho_max    0.217870       0.001301      0.313763  0.395582
# pto_orvalho_min   -0.236221       0.137937     -0.160736 -0.148546
# pressao           -0.035955       0.106557     -0.130401  0.064973
# pressao_max        0.035348       0.101206     -0.063660  0.176059
# pressao_min        0.011564       0.105036     -0.089884  0.134455
# vento_vel          1.000000      -0.401777      0.843948  0.758687
# vento_direcao     -0.401777       1.000000     -0.385291 -0.193128
# vento_rajada       0.843948      -0.385291      1.000000  0.703881
# radiacao           0.758687      -0.193128      0.703881  1.000000
# precipitacao       0.020048       0.040814      0.160708 -0.041466
#
#                   precipitacao
# hora                  0.087173
# temp_inst            -0.043121
# temp_max              0.012613
# temp_min             -0.033898
# umid_inst             0.107823
# umid_max              0.101092
# umid_min              0.048973
# pto_orvalho_inst      0.142016
# pto_orvalho_max       0.154190
# pto_orvalho_min       0.130741
# pressao              -0.015621
# pressao_max          -0.010277
# pressao_min          -0.022630
# vento_vel             0.020048
# vento_direcao         0.040814
# vento_rajada          0.160708
# radiacao             -0.041466
# precipitacao          1.000000

# %% [markdown]
# # HeatMap Correlação

# %%
ax = plt.subplots(figsize=(11, 8))

plt.title('Correlação da Features',y=1,size=16)

sns.heatmap(corr,square = True,  vmax=0.8)

# %% [markdown]
# ## Zoomed HeatMap

# %%
plt.subplots(figsize=(15, 10))

plt.title('Correlação da Features',y=1,size=16)

sns.heatmap(corr, center=True, square=True, annot=True, cmap="YlOrBr");

# %% [markdown]
# - ### Grafícos de Dispersão

# %%
portogrande.columns
# Out:
# Index(['codigo_estacao', 'data', 'hora', 'temp_inst', 'temp_max', 'temp_min',
#        'umid_inst', 'umid_max', 'umid_min', 'pto_orvalho_inst',
#        'pto_orvalho_max', 'pto_orvalho_min', 'pressao', 'pressao_max',
#        'pressao_min', 'vento_vel', 'vento_direcao', 'vento_rajada', 'radiacao',
#        'precipitacao'],
#       dtype='object')

# %%
plt.scatter(portogrande.hora, portogrande.precipitacao)

# %%
plt.scatter(portogrande.temp_inst, portogrande.precipitacao)

# %% [markdown]
# # Verificar Distribuição

# %% [markdown]
# - ### Boxplot

# %%
# precipitacao
sns.distplot(portogrande.precipitacao)
# Out:
# /home/douglas/miniconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
# temperatura
plt.subplots(figsize=(12, 8))

sns.boxplot(data=portogrande.loc[:, ["temp_inst", "temp_max", "temp_min"]]);

# %%
sns.distplot(portogrande.temp_inst)
sns.distplot(portogrande.temp_max)
sns.distplot(portogrande.temp_min)
plt.legend(labels=['Temp inst','Temp Max','Temp Min'], ncol=3, loc='upper left');

# %%
portogrande.columns
# Out:
# Index(['codigo_estacao', 'data', 'hora', 'temp_inst', 'temp_max', 'temp_min',
#        'umid_inst', 'umid_max', 'umid_min', 'pto_orvalho_inst',
#        'pto_orvalho_max', 'pto_orvalho_min', 'pressao', 'pressao_max',
#        'pressao_min', 'vento_vel', 'vento_direcao', 'vento_rajada', 'radiacao',
#        'precipitacao'],
#       dtype='object')

# %%
# umidade 
plt.subplots(figsize=(12, 8))

sns.boxplot(data=portogrande.loc[:, ["umid_inst", "umid_max", "umid_min"]]);

# %%
portogrande.columns
# Out:
# Index(['codigo_estacao', 'data', 'hora', 'temp_inst', 'temp_max', 'temp_min',
#        'umid_inst', 'umid_max', 'umid_min', 'pto_orvalho_inst',
#        'pto_orvalho_max', 'pto_orvalho_min', 'pressao', 'pressao_max',
#        'pressao_min', 'vento_vel', 'vento_direcao', 'vento_rajada', 'radiacao',
#        'precipitacao'],
#       dtype='object')

# %%
sns.distplot(portogrande.umid_inst)
sns.distplot(portogrande.umid_max)
sns.distplot(portogrande.umid_min)

# %%
# pt_orvalho (um negocio que ne nem sei o que é)
plt.subplots(figsize=(12, 8))

sns.boxplot(data=portogrande.loc[:,["pto_orvalho_inst", "pto_orvalho_max", "pto_orvalho_min"]]);

# %%
# pressão atmosferica
plt.subplots(figsize=(12, 8))

sns.boxplot(data=portogrande.loc[:,["pressao", "pressao_max","pressao_min"]]);

# %%
# visão de geral

features = ["temp_inst", "umid_inst", "pto_orvalho_inst",
            "pressao", "vento_vel", "vento_direcao",
            "vento_rajada", "radiacao","precipitacao"]

plt.subplots(figsize=(12, 8))


sns.boxplot(data=portogrande.loc[:, features]);

# %% [markdown]
# - ### Transformações de Johnson, log Normal e a distribuição Normal

# %%
y = portogrande['precipitacao']

plt.figure(1); plt.title('Johnson SU')
sns.distplot(y, kde=False, fit=st.johnsonsu)

plt.figure(2); plt.title('Normal')
sns.distplot(y, kde=False, fit=st.norm)

plt.figure(3); plt.title('Log Normal')
sns.distplot(y, kde=False, fit=st.lognorm)
# Out:
# /home/douglas/miniconda3/lib/python3.7/site-packages/scipy/stats/_continuous_distns.py:4018: RuntimeWarning: divide by zero encountered in log
#   trm = _norm_pdf(a + b * np.log(x + np.sqrt(x2+1)))

# %% [markdown]
# # Testes de Hipotese
# - Função para gerar samples

# %%
def sample(df, col_name, n=100, seed=42):
    np.random.seed(seed)    
    random_idx = np.random.choice(df[col_name].dropna().index, size=n, replace=False)
    return df.loc[random_idx, col_name]

# %%
# qqplot de precipitacao do municipio de Porto Grande
sm.qqplot(portogrande.precipitacao, fit=True, line="45");

# %%
sm.qqplot(portogrande.temp_inst, fit=True, line="45");  # temperatura no instante

# %%
sm.qqplot(portogrande.temp_max, fit=True, line="45"); # temperatura maxima

# %%
sm.qqplot(portogrande.temp_min, fit=True, line="45"); # temperatura miníma

# %%
sm.qqplot(portogrande.umid_inst, fit=True, line="45"); # umidade no instante

# %%
sm.qqplot(portogrande.umid_max, fit=True, line="45"); # umidade maxima

# %%
sm.qqplot(portogrande.umid_min, fit=True, line="45"); # umidade maxima

# %% [markdown]
# # Teste de Hipotese de Normalidade

# %% [markdown]
# ### Shapiro-Wilk
#
# O teste de Shapiro-Wilk é um teste de aderência à distribuição normal, que abreviamos para teste de normalidade. Nosso intuito é verificar se uma dada amostra veio ou não de uma distribuição normal.
#
# Não precisamos e não entraremos nos detalhes da sua estatística de teste. Tudo que precisamos saber por ora é:
#
# * A hipótese nula, $H_{0}$, é a normalidade dos dados e A hipotese Alternativa, $H_{a}$ é não normalidade
#   * Se o valor-p for menor que o nível de significância $\alpha$, então temos evidências de que os dados não vêm de uma distribuição normal.
#   * Se o valor-p for maior que $\alpha$, então não podemos afimar que os dados não vêm de uma distribuição normal (o que é sutilmente diferente de afirmar que eles _vêm_ de uma distribuição normal. Cuidado!).
# * Apesar de ter tendência a melhores resultados quanto maior a amostra, a maior parte das implementações não suporta computações com amostras muito grandes.
#   * A implementação do SciPy por exemplo só suporta até 5000 observações.
# * É altamente aconselhado fazer o teste em conjunto com uma análise gráfica de um _q-q plot_.

# %%
ptg_amostra = sample(portogrande,'precipitacao',3000) # amostra
teste = st.shapiro(ptg_amostra) # teste de shapiro

# resultado
if teste[1] < 0.05:
    print('PORTO GRANDE - AP: Precipitação')
    print("--------------------")
    print(f'{teste}\nP_valor: {teste[1]} menor que Alpha = 0.05')
    print('Ha => Os dados não vem de uma distribuição normal')
else:
    print('PORTO GRANDE - AP')
    print("--------------------")
    print(f'{teste}\nP_valor: {teste[1]} maior que Alpha = 0.05')
    print('H0 => Os dados vem de uma distribuição normal')
# Out:
# PORTO GRANDE - AP: Precipitação
# --------------------
# (0.24920368194580078, 0.0)
# P_valor: 0.0 menor que Alpha = 0.05
# Ha => Os dados não vem de uma distribuição normal

# %% [markdown]
# ### Jarque-Bera
#
# Assim como Shapiro-Wilk, o teste de Jarque-Bera é um teste de aderência à distribuição normal com $H_{0}$ sendo a normalidade dos dados. A diferença reside na estatística de teste utilizada.
#
# A estatística de teste é baseada na assimetria (_skewness_) e curtose (_kurtosis_) excessiva da amostra. Se a amostra vem de uma distribuição normal, então esses valores devem ser muito próximos de zero. Se isso acontecer, então a estatística de teste tem distribuição $\chi^{2}$ com dois graus de liberdade.
#
# No entanto, se a amostra for pequena, podemos ter muitos falsos negativos (Erro Tipo I) ao utilizarmos a distribuição $\chi^{2}$, ou seja, rejeitamos $H_{0}$ quando ela é verdadeira.
#
# Para evitar isso, as implementações costumam utilizar aproximações por Monte-Carlo quando $n$ é pequeno, reservando a aproximação $\chi^{2}$ para amostras grandes.
#
# Novamente, é altamente aconselhado complementar o resultado desse teste com um _q-q plot_.

# %%
ptg_amostra = sample(portogrande,'precipitacao',3000) # amostra
teste = st.jarque_bera(ptg_amostra) # teste de shapiro

# resultado
if teste[1] < 0.05:
    print('PORTO GRANDE - AP')
    print("--------------------")
    print(f'{teste}\nP_valor: {teste[1]} menor que Alpha = 0.05')
    print('Ha => Os dados não vem de uma distribuição normal')
else:
    print('PORTO GRANDE - AP')
    print("--------------------")
    print(f'{teste}\nP_valor: {teste[1]} maior que Alpha = 0.05')
    print('H0 => Os dados vem de uma distribuição normal')
# Out:
# PORTO GRANDE - AP
# --------------------
# (717395.8707180631, 0.0)
# P_valor: 0.0 menor que Alpha = 0.05
# Ha => Os dados não vem de uma distribuição normal
