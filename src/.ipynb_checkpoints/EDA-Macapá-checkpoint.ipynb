# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mtl
import scipy.stats as st
import missingno  as msno
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# # Trabalhando com a base de Macapá

# %% [markdown]
# - ### Vamos conhecer um pouco sobre a base de dados

# %%
macapa = pd.read_csv('../data/macapa.txt')

# %%
# dimensão do dataframe
macapa.shape
# Out:
# (8604, 20)

# %%
# features
macapa.columns
# Out:
# Index(['codigo_estacao', 'data', 'hora', 'temp_inst', 'temp_max', 'temp_min',
#        'umid_inst', 'umid_max', 'umid_min', 'pto_orvalho_inst',
#        'pto_orvalho_max', 'pto_orvalho_min', 'pressao', 'pressao_max',
#        'pressao_min', 'vento_vel', 'vento_direcao', 'vento_rajada', 'radiacao',
#        'precipitacao'],
#       dtype='object')

# %%
# algumas informações
macapa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8604 entries, 0 to 8603
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   codigo_estacao    8604 non-null   object
#  1   data              8604 non-null   object
#  2   hora              8604 non-null   int64
#  3   temp_inst         8604 non-null   float64
#  4   temp_max          8604 non-null   float64
#  5   temp_min          8604 non-null   float64
#  6   umid_inst         8604 non-null   int64
#  7   umid_max          8604 non-null   int64
#  8   umid_min          8604 non-null   int64
#  9   pto_orvalho_inst  8604 non-null   float64
#  10  pto_orvalho_max   8604 non-null   float64
#  11  pto_orvalho_min   8604 non-null   float64
#  12  pressao           8604 non-null   float64
#  13  pressao_max       8604 non-null   float64
#  14  pressao_min       8604 non-null   float64
#  15  vento_vel         7726 non-null   float64
#  16  vento_direcao     7731 non-null   float64
#  17  vento_rajada      7720 non-null   object
#  18  radiacao          8604 non-null   float64
#  19  precipitacao      8602 non-null   object
# dtypes: float64(12), int64(4), object(4)
# memory usage: 1.3+ MB

# %%
# tabela percentual de dados faltantes

total = macapa.isnull().sum().sort_values(ascending=False)
percent = (macapa.isnull().sum()/macapa.isnull().count()).sort_values(ascending=False)


missing_data = pd.concat([total, percent], axis=1,join='outer', keys=['Dados Ausentes', '% Percentual'])
missing_data.index.name =' Variaveis numericas'
missing_data.head(20)
# Out:
#                       Dados Ausentes  % Percentual
#  Variaveis numericas
# vento_rajada                     884      0.102743
# vento_vel                        878      0.102046
# vento_direcao                    873      0.101464
# precipitacao                       2      0.000232
# umid_max                           0      0.000000
# data                               0      0.000000
# hora                               0      0.000000
# temp_inst                          0      0.000000
# temp_max                           0      0.000000
# temp_min                           0      0.000000
# umid_inst                          0      0.000000
# pto_orvalho_inst                   0      0.000000
# umid_min                           0      0.000000
# radiacao                           0      0.000000
# pto_orvalho_max                    0      0.000000
# pto_orvalho_min                    0      0.000000
# pressao                            0      0.000000
# pressao_max                        0      0.000000
# pressao_min                        0      0.000000
# codigo_estacao                     0      0.000000

# %%
macapa.vento_rajada.value_counts()
# Out:
# 2.3     175
# 2.6     160
# 3.0     151
# 2.9     148
# 3.5     142
#        ...
# 12.3      1
# 0.7       1
# 13.7      1
# 0.9       1
# 13.5      1
# Name: vento_rajada, Length: 129, dtype: int64

# %%
macapa.vento_vel.value_counts()
# Out:
# 1.1    439
# 1.0    420
# 1.2    398
# 0.8    380
# 0.9    378
# 1.3    352
# 0.7    320
# 1.4    292
# 1.5    258
# 0.6    251
# 1.7    229
# 1.6    202
# 1.8    189
# 2.5    183
# 1.9    178
# 2.8    175
# 2.2    174
# 2.1    171
# 2.7    169
# 2.0    166
# 2.3    160
# 3.3    148
# 2.4    148
# 2.6    146
# 3.1    142
# 3.2    142
# 2.9    135
# 3.4    129
# 0.5    121
# 3.0    116
# 3.5    112
# 3.7     99
# 3.6     95
# 3.8     82
# 0.4     81
# 4.0     77
# 3.9     73
# 4.1     71
# 4.2     47
# 4.3     41
# 0.3     40
# 4.4     39
# 4.6     29
# 4.5     27
# 4.7     27
# 0.2     18
# 4.8     11
# 5.3      8
# 4.9      7
# 5.0      6
# 5.1      5
# 5.4      4
# 0.1      4
# 5.2      3
# 5.5      3
# 6.5      2
# 6.0      1
# 5.7      1
# 6.2      1
# 5.8      1
# Name: vento_vel, dtype: int64

# %%
# 0s 10 valore que mais se repetem na coluna precipitação
macapa.precipitacao.value_counts()
# Out:
# 0.0     6949
# ////     742
# 0.2      242
# 0.4      107
# 0.8       66
#         ...
# 17.0       1
# 23.4       1
# 15.0       1
# 31.0       1
# 17.8       1
# Name: precipitacao, Length: 83, dtype: int64

# %%
# algumas caracteristicas estatisticas
macapa.describe()
# Out:
#               hora    temp_inst     temp_max     temp_min    umid_inst  \
# count  8604.000000  8604.000000  8604.000000  8604.000000  8604.000000
# mean     11.503138    27.309263    27.817445    26.845979    78.780219
# std       6.919918     2.687537     2.867672     2.514849    13.110096
# min       0.000000    22.000000    22.100000    21.500000    35.000000
# 25%       6.000000    25.000000    25.300000    24.700000    69.000000
# 50%      12.000000    26.800000    27.400000    26.200000    82.000000
# 75%      17.250000    29.400000    30.200000    28.800000    91.000000
# max      23.000000    34.700000    34.800000    33.400000    96.000000
#
#           umid_max     umid_min  pto_orvalho_inst  pto_orvalho_max  \
# count  8604.000000  8604.000000       8604.000000      8604.000000
# mean     81.052882    76.324268         23.022513        23.451104
# std      12.009794    14.121594          0.904848         0.868365
# min      38.000000    31.000000         16.000000        17.500000
# 25%      72.000000    65.000000         22.500000        23.000000
# 50%      85.000000    79.000000         23.100000        23.500000
# 75%      92.000000    89.000000         23.600000        24.000000
# max      96.000000    96.000000         26.300000        26.800000
#
#        pto_orvalho_min      pressao  pressao_max  pressao_min    vento_vel  \
# count      8604.000000  8604.000000  8604.000000  8604.000000  7726.000000
# mean         22.606416  1009.978266  1010.265098  1009.692259     1.914613
# std           1.019314     1.957438     1.939549     1.950011     1.093710
# min          14.600000  1003.600000  1003.800000  1003.400000     0.100000
# 25%          22.100000  1008.600000  1008.900000  1008.300000     1.000000
# 50%          22.800000  1010.000000  1010.300000  1009.700000     1.600000
# 75%          23.300000  1011.400000  1011.700000  1011.100000     2.700000
# max          25.000000  1015.500000  1015.800000  1015.500000     6.500000
#
#        vento_direcao     radiacao
# count    7731.000000  8604.000000
# mean      137.076575   820.151086
# std        93.360529  1141.286828
# min         1.000000    -3.600000
# 25%        61.500000    -3.420000
# 50%       126.000000    30.005000
# 75%       196.000000  1561.000000
# max       360.000000  3890.000000

# %%
# Variaveis numéricas
varNum = macapa.select_dtypes(include=[np.number])
varNum.columns
# Out:
# Index(['hora', 'temp_inst', 'temp_max', 'temp_min', 'umid_inst', 'umid_max',
#        'umid_min', 'pto_orvalho_inst', 'pto_orvalho_max', 'pto_orvalho_min',
#        'pressao', 'pressao_max', 'pressao_min', 'vento_vel', 'vento_direcao',
#        'radiacao'],
#       dtype='object')

# %%
# variaveis categoricas
varCat = macapa.select_dtypes(include=[np.object])
varCat.columns
# Out:
# Index(['codigo_estacao', 'data', 'vento_rajada', 'precipitacao'], dtype='object')

# %%
# resumindo
print(f'Total de Variaveis Numericas: {varNum.columns.value_counts().sum()}')
print(f'Total de Variaveis Categoricas: {varCat.columns.value_counts().sum()}')
# Out:
# Total de Variaveis Numericas: 16
# Total de Variaveis Categoricas: 4

# %% [markdown]
# # Visualizando Valores Ausentes

# %% [markdown]
# - ### Matriz de Nulidade

# %%
msno.matrix(macapa)

# %% [markdown]
# - ## HeatMap de Nulidade
#
# Mede a correlação de nulidade: Quão fortemente a presença ou ausência de uma variável afeta a presença de outra:
#
# ### Legenda:
#
# - A correlação de nulidade varia de -1 a 0
# - correlação de nulidade varia de -1 (se uma variável parece a outra definitivamente não aparece)
# - Se for 0 (variáveis que aparecem ou não aparecem não têm efeito uma sobre a outra)
# - Se for 1 (se uma variável aparece, a outra definitivamente também tem influencia sobre a outra)
# - As entradas marcadas <1ou > -1 estão com uma correlação próxima de ser exatamente negativa ou
#   positiva.

# %%
msno.heatmap(macapa)

# %% [markdown]
# - ## Grafíco de Barras de Nulidade

# %%
msno.bar(macapa.sample(1000))

# %% [markdown]
# # Estimando os valores de Skewness e Kurtose

# %%
# Estimando Skewness 
macapa.skew()
# Out:
# hora               -0.001092
# temp_inst           0.449021
# temp_max            0.369087
# temp_min            0.519510
# umid_inst          -0.581108
# umid_max           -0.714701
# umid_min           -0.448266
# pto_orvalho_inst   -0.878786
# pto_orvalho_max    -0.329269
# pto_orvalho_min    -1.260088
# pressao            -0.036723
# pressao_max        -0.067762
# pressao_min        -0.002488
# vento_vel           0.736734
# vento_direcao       0.643492
# radiacao            1.117274
# dtype: float64

# %%
# grafico dos valores de Skewness do dataset
sns.distplot(macapa.skew(),color='blue',axlabel ='Skewness')

# %%
# Estimando Kurtose
macapa.kurt()
# Out:
# hora               -1.203028
# temp_inst          -0.902071
# temp_max           -1.005798
# temp_min           -0.815527
# umid_inst          -0.803118
# umid_max           -0.611709
# umid_min           -0.953982
# pto_orvalho_inst    2.493275
# pto_orvalho_max     1.106963
# pto_orvalho_min     3.344362
# pressao            -0.358456
# pressao_max        -0.356026
# pressao_min        -0.345852
# vento_vel          -0.301801
# vento_direcao      -0.303502
# radiacao           -0.212738
# dtype: float64

# %%
# Comparando a distribuição com e verificando sua Kurtose
plt.figure(figsize = (12,8))
sns.distplot(macapa.kurt(),color='r',axlabel ='Kurtosis',norm_hist= False, kde = True,rug = False)
plt.show()

# %%
target = np.log(macapa['umid_inst'])
target.skew()
plt.hist(target,color='blue')
# Out:
# (array([3.000e+00, 5.000e+00, 5.000e+01, 1.900e+02, 4.360e+02, 8.760e+02,
#         8.890e+02, 1.303e+03, 1.491e+03, 3.361e+03]),
#  array([3.55534806, 3.65624807, 3.75714809, 3.8580481 , 3.95894811,
#         4.05984813, 4.16074814, 4.26164815, 4.36254817, 4.46344818,
#         4.56434819]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Correlação

# %% [markdown]
# - ## Dendrograma
#
# Permite correlacionar mais completamente a conclusão das variáveis, revelando tendências mais profundas do que as pares aos pares visíveis no mapa de calor da correlação:

# %%
msno.dendrogram(macapa)

# %% [markdown]
# - ### Matrix de Correlação

# %%
corr = macapa.corr(method = 'pearson')
corr
# Out:
#                       hora  temp_inst  temp_max  temp_min  umid_inst  \
# hora              1.000000   0.517565  0.553078  0.494125  -0.510409
# temp_inst         0.517565   1.000000  0.974701  0.967958  -0.963265
# temp_max          0.553078   0.974701  1.000000  0.958971  -0.949100
# temp_min          0.494125   0.967958  0.958971  1.000000  -0.949139
# umid_inst        -0.510409  -0.963265 -0.949100 -0.949139   1.000000
# umid_max         -0.482657  -0.917509 -0.918693 -0.959793   0.965822
# umid_min         -0.546684  -0.938383 -0.967446 -0.939310   0.973286
# pto_orvalho_inst -0.180199  -0.270632 -0.290370 -0.325746   0.504523
# pto_orvalho_max   0.029298   0.032281  0.027806 -0.063409   0.188646
# pto_orvalho_min  -0.364771  -0.452389 -0.488684 -0.478483   0.633438
# pressao          -0.283134  -0.214351 -0.241370 -0.293332   0.219169
# pressao_max      -0.258074  -0.149495 -0.176663 -0.231238   0.156335
# pressao_min      -0.281205  -0.177852 -0.206089 -0.255322   0.181992
# vento_vel         0.458222   0.750252  0.780666  0.751637  -0.764212
# vento_direcao     0.062431  -0.108565 -0.096657 -0.111542   0.114225
# radiacao          0.459457   0.793350  0.771375  0.704535  -0.755419
#
#                   umid_max  umid_min  pto_orvalho_inst  pto_orvalho_max  \
# hora             -0.482657 -0.546684         -0.180199         0.029298
# temp_inst        -0.917509 -0.938383         -0.270632         0.032281
# temp_max         -0.918693 -0.967446         -0.290370         0.027806
# temp_min         -0.959793 -0.939310         -0.325746        -0.063409
# umid_inst         0.965822  0.973286          0.504523         0.188646
# umid_max          1.000000  0.958691          0.539248         0.307921
# umid_min          0.958691  1.000000          0.477859         0.183381
# pto_orvalho_inst  0.539248  0.477859          1.000000         0.829891
# pto_orvalho_max   0.307921  0.183381          0.829891         1.000000
# pto_orvalho_min   0.667642  0.660469          0.883460         0.723132
# pressao           0.294510  0.245183          0.141916         0.162925
# pressao_max       0.235836  0.183888          0.112106         0.169483
# pressao_min       0.258035  0.210785          0.116687         0.157059
# vento_vel        -0.744705 -0.778043         -0.319227        -0.036602
# vento_direcao     0.124921  0.097138          0.054686         0.086880
# radiacao         -0.655879 -0.719536         -0.230337         0.141109
#
#                   pto_orvalho_min   pressao  pressao_max  pressao_min  \
# hora                    -0.364771 -0.283134    -0.258074    -0.281205
# temp_inst               -0.452389 -0.214351    -0.149495    -0.177852
# temp_max                -0.488684 -0.241370    -0.176663    -0.206089
# temp_min                -0.478483 -0.293332    -0.231238    -0.255322
# umid_inst                0.633438  0.219169     0.156335     0.181992
# umid_max                 0.667642  0.294510     0.235836     0.258035
# umid_min                 0.660469  0.245183     0.183888     0.210785
# pto_orvalho_inst         0.883460  0.141916     0.112106     0.116687
# pto_orvalho_max          0.723132  0.162925     0.169483     0.157059
# pto_orvalho_min          1.000000  0.167340     0.123681     0.141841
# pressao                  0.167340  1.000000     0.982966     0.986119
# pressao_max              0.123681  0.982966     1.000000     0.988200
# pressao_min              0.141841  0.986119     0.988200     1.000000
# vento_vel               -0.450635 -0.248411    -0.205071    -0.229030
# vento_direcao            0.027720  0.180163     0.186334     0.180317
# radiacao                -0.393786  0.010882     0.110613     0.073384
#
#                   vento_vel  vento_direcao  radiacao
# hora               0.458222       0.062431  0.459457
# temp_inst          0.750252      -0.108565  0.793350
# temp_max           0.780666      -0.096657  0.771375
# temp_min           0.751637      -0.111542  0.704535
# umid_inst         -0.764212       0.114225 -0.755419
# umid_max          -0.744705       0.124921 -0.655879
# umid_min          -0.778043       0.097138 -0.719536
# pto_orvalho_inst  -0.319227       0.054686 -0.230337
# pto_orvalho_max   -0.036602       0.086880  0.141109
# pto_orvalho_min   -0.450635       0.027720 -0.393786
# pressao           -0.248411       0.180163  0.010882
# pressao_max       -0.205071       0.186334  0.110613
# pressao_min       -0.229030       0.180317  0.073384
# vento_vel          1.000000      -0.078960  0.621592
# vento_direcao     -0.078960       1.000000  0.016243
# radiacao           0.621592       0.016243  1.000000

# %% [markdown]
# - ### HeatMap Correlação

# %%
ax = plt.subplots(figsize=(11, 8))

plt.title('Correlação da Features',y=1,size=16)

sns.heatmap(corr,square = True,  vmax=0.8)

# %% [markdown]
# - ### Zoomed HeatMap

# %%
plt.subplots(figsize=(15, 10))

plt.title('Correlação da Features',y=1,size=16)

sns.heatmap(corr, center=True, square=True, annot=True, cmap="YlOrBr");

# %% [markdown]
# # Verificar Distribuição

# %% [markdown]
# - ### Boxplot

# %%
# temperatura
plt.subplots(figsize=(12, 8))

sns.boxplot(data=macapa.loc[:, ["temp_inst", "temp_max", "temp_min"]]);

# %%
sns.distplot(macapa.temp_inst)
sns.distplot(macapa.temp_max)
sns.distplot(macapa.temp_min)
plt.legend(labels=['Temp inst','Temp Max','Temp Min'], ncol=3, loc='upper left');

# %%
# umidade 
plt.subplots(figsize=(12, 8))

sns.boxplot(data=macapa.loc[:, ["umid_inst", "umid_max", "umid_min"]]);

# %%
sns.distplot(macapa.umid_inst)
sns.distplot(macapa.umid_max)
sns.distplot(macapa.umid_min)
plt.legend(labels=['Umidade instante','Umidade Max','Umidade min'], ncol=3, loc='upper left');

# %%
# pt_orvalho (um negocio que ne nem sei o que é)
plt.subplots(figsize=(12, 8))

sns.boxplot(data=macapa.loc[:,["pto_orvalho_inst", "pto_orvalho_max", "pto_orvalho_min"]]);

# %%
sns.distplot(macapa.pto_orvalho_inst)
sns.distplot(macapa.pto_orvalho_max)
sns.distplot(macapa.pto_orvalho_min)
plt.legend(labels=['Orv inst','Orv Max','Orv Min'], ncol=3, loc='upper left');

# %%
# pressão atmosferica
plt.subplots(figsize=(12, 8))

sns.boxplot(data=macapa.loc[:,["pressao", "pressao_max","pressao_min"]]);

# %%
sns.distplot(macapa.pressao)
sns.distplot(macapa.pressao_max)
sns.distplot(macapa.pressao_min)
plt.legend(labels=['Pressão','Pressão Max','Pressão Min'], ncol=3, loc='upper left');

# %%
# visão de geral

features = ["temp_inst", "umid_inst", "pto_orvalho_inst",
            "pressao", "vento_vel", "vento_direcao",
            "vento_rajada", "radiacao","precipitacao"]

plt.subplots(figsize=(12, 8))


sns.boxplot(data=macapa.loc[:, features]);
